# %% [markdown]
# Problem Statement: Avocado is a fruit consumed by people heavily in the United States.
#
# Content
#
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.

# %%
# Importing Necessery liabraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
import warnings 
warnings.simplefilter(action='ignore',category=FutureWarning)

# %%
#  Importing dataset

df = pd.read_csv(r"C:\Users\Abhijeet\Desktop\My Data\Datasets\Avacado\avocado.csv")

# %%
# Printing first five rows of  the dataset
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
df.shape
# Out:
# (18249, 14)

# %% [markdown]
# Here we have 1470 rows and 35 diffrent columns in our datset.

# %%
# Checking datatypes of column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Column observation
# Unnamed - This is an irrelveant column containing the index or serial number of the rows we might drop it
#
# Date - This is Object type of column containing the date of observation'
#
# AveragePrice - This is intger type of column containing the average price per piece in USD
#
# Total Volume - This is also an integer type of column showing the number of units or acacados sold
#
# 4046/4225/4770- Type integer - This columns indicates the PLU numbers assigned to a avacado based on its size
#
# Total bags - This column is of integer type and indicates the total number of bags sold
#
# Small Bags - This column is of integer type and indicates the total number of small bags sold
#
# Large Bags - This column is of integer type and indicates the total number of large bags sold
#
# XLarge Bags - This column is of integer type and indicates the total number of extra large bags sold
#
# Type - This column is of Object type and indicates type of Avacado ( conventional or Organic)
#
# Year - This is integer type of column showing Year of observation
#
# Region - The city or the region of observation

# %% [markdown]
# Dropping first column as it is an irrelveant column containing the index or serial number

# %%
df.drop('Unnamed: 0', axis=1, inplace = True)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.shape
# Out:
# (18249, 13)

# %%
# Checking for null values

df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
# Checking for duplicate calues
df.duplicated().sum()
# Out:
# 0

# %%
# Checking data Stats

df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# std    9.862424e+05  7.461785e+05  2.439660e+05   17692.894652      0.939938
# min    0.000000e+00  0.000000e+00  0.000000e+00       0.000000   2015.000000
# 25%    5.088640e+03  2.849420e+03  1.274700e+02       0.000000   2015.000000
# 50%    3.974383e+04  2.636282e+04  2.647710e+03       0.000000   2016.000000
# 75%    1.107834e+05  8.333767e+04  2.202925e+04     132.500000   2017.000000
# max    1.937313e+07  1.338459e+07  5.719097e+06  551693.650000   2018.000000

# %%
# Chacking for correlation

df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.177088   -0.174730   -0.172940    -0.117592  0.093197
# Total Volume    0.963047    0.967238    0.880640     0.747157  0.017193
# 4046            0.920057    0.925280    0.838645     0.699377  0.003353
# 4225            0.905787    0.916031    0.810015     0.688809 -0.009559
# 4770            0.792314    0.802733    0.698471     0.679861 -0.036531
# Total Bags      1.000000    0.994335    0.943009     0.804233  0.071552
# Small Bags      0.994335    1.000000    0.902589     0.806845  0.063915
# Large Bags      0.943009    0.902589    1.000000     0.710858  0.087891
# XLarge Bags     0.804233    0.806845    0.710858     1.000000  0.081033
# year            0.071552    0.063915    0.087891     0.081033  1.000000

# %%
plt.figure(figsize= (12,10))
sns.heatmap(df.corr(),annot =True )
plt.show()

# %% [markdown]
# Since Total bags column represents the sum of small/ large and extra large bags high correlation exists between this columns
#
# Also Total volume represents the cumulated sell in units of all sizes of Avacados this 4 columns also shws high correlation.

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
sns.distplot(df['AveragePrice'])
plt.show()

# %% [markdown]
# Here we found that Average price ranges from 0.5 to 2.5 and has mean 1.40

# %%
plt.figure(figsize = (15,5))
sns.scatterplot(y = 'Total Volume', x = 'AveragePrice', data  = df)
plt.show()

# %% [markdown]
# Above graph shows that more volume was sold for price range 0.5 to 1.8 .
#
# Total volume is denced between 0 to 1 and 3 to 4

# %%
# Splitting date column between days and month
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df['Date'].apply(lambda x:x.month)
df['Day']=df['Date'].apply(lambda x:x.day)

# %%
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month  Day
# 0  Albany     12   27
# 1  Albany     12   20
# 2  Albany     12   13
# 3  Albany     12    6
# 4  Albany     11   29

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x="Month", y="AveragePrice", hue='type', data=df)
plt.show()

# %% [markdown]
# Here we can see that avg price for both type of Avacados increases from 6 to 12 month
#
# Also avg price for Organic Avacados is greater than Conventional Avacados

# %%
sns.countplot(df['type'])
plt.show()

# %%
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# We can see our type column is well balanced between Conventional and Organic Avacados

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
df['region'].value_counts()
# Out:
# Pittsburgh             338
# TotalUS                338
# SanFrancisco           338
# Charlotte              338
# Chicago                338
# Tampa                  338
# Philadelphia           338
# NewOrleansMobile       338
# Denver                 338
# Seattle                338
# West                   338
# PhoenixTucson          338
# StLouis                338
# Houston                338
# LasVegas               338
# Syracuse               338
# Sacramento             338
# HartfordSpringfield    338
# DallasFtWorth          338
# Nashville              338
# SouthCarolina          338
# Spokane                338
# California             338
# Atlanta                338
# Louisville             338
# Jacksonville           338
# Portland               338
# Boise                  338
# LosAngeles             338
# HarrisburgScranton     338
# SouthCentral           338
# SanDiego               338
# GreatLakes             338
# BuffaloRochester       338
# Boston                 338
# RichmondNorfolk        338
# BaltimoreWashington    338
# NewYork                338
# Columbus               338
# Midsouth               338
# RaleighGreensboro      338
# Orlando                338
# NorthernNewEngland     338
# CincinnatiDayton       338
# Albany                 338
# Northeast              338
# MiamiFtLauderdale      338
# Roanoke                338
# GrandRapids            338
# Plains                 338
# Indianapolis           338
# Detroit                338
# Southeast              338
# WestTexNewMexico       335
# Name: region, dtype: int64

# %% [markdown]
# Also we can see that we have equal number of counts from each region

# %%
plt.figure(figsize = (30,15),)
sns.barplot(x = 'region', y = 'Total Volume', data = df)
plt.xticks(rotation = 90, size = 12)
plt.title('Volume vs Region')
plt.tight_layout()

# %% [markdown]
# In above graph we can see that sales volume is more for regions like California, GreatLakes, LA, Midsouth , Northeast,SouthCentral, Southeast and West

# %%
sns.barplot(x = 'Month', y ='AveragePrice',data= df)
plt.show()

# %% [markdown]
# We can see in above graph avg price increases from 6 to 10 months and then decreases

# %%
sns.barplot(x = 'Month', y ='Total Volume',data= df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Total Volume'>

# %% [markdown]
# In above graph it is clearly seen that sales volume decreses continously from 5th month upto 11th month

# %%
sns.barplot(x = 'year', y ='Total Volume', data = df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Total Volume'>

# %% [markdown]
# We can see in above graph that sales volume increases from 2015 to 2017 and increases drastically in 2018

# %%
region_list=list(df.region.unique())
average_price=[]

for i in region_list:
    x=df[df.region==i]
    region_average=sum(x.AveragePrice)/len(x)
    average_price.append(region_average)

df1=pd.DataFrame({'region_list':region_list,'average_price':average_price})
new_index=df1.average_price.sort_values(ascending=False).index.values
sorted_data=df1.reindex(new_index)

plt.figure(figsize=(24,10))
ax=sns.barplot(x=sorted_data.region_list,y=sorted_data.average_price)

plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('Average Price of Avocado According to Region')
plt.show()

# %% [markdown]
# In above graph we can see that Avg price is higher in hartfordSpringfield , sanfransico, NewYork, Philadelpia and so on
#
# Also , Avg price is lower in regions SouthCentral, dallasFtworth, Houston

# %%
sns.pairplot(df, x_vars=['4046', '4225', '4770'], y_vars='Total Volume',height = 8, kind = 'scatter')

# %% [markdown]
# Above graph indicates the total volume sold wrt to the sizes in we can see above size is highly denced between 0 to .5

# %%
sns.pairplot(df, x_vars=['Small Bags', 'Large Bags', 'XLarge Bags'], y_vars = 'Total Bags',height = 8, kind = 'scatter')

# %% [markdown]
# Above graph shows strong linear regression between small bags and Total bags and also shows that small, large and xlarge bags are highly correlated with the Total bags column

# %%
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month  Day
# 0  Albany     12   27
# 1  Albany     12   20
# 2  Albany     12   13
# 3  Albany     12    6
# 4  Albany     11   29

# %% [markdown]
# Now As we have already splitted date column into day and month and we already have year column in our dataset we can drop Date column

# %%
df.drop('Date', axis=1, inplace = True)

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region  Month  Day
# 0     8603.62       93.25          0.0  conventional  2015  Albany     12   27
# 1     9408.07       97.49          0.0  conventional  2015  Albany     12   20
# 2     8042.21      103.14          0.0  conventional  2015  Albany     12   13
# 3     5677.40      133.76          0.0  conventional  2015  Albany     12    6
# 4     5986.26      197.69          0.0  conventional  2015  Albany     11   29

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  object
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  object
#  12  Month         18249 non-null  int64
#  13  Day           18249 non-null  int64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# Before processing further we need to convert type and region columns into integer , we will use Label encider to encode the columns

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['type']=le.fit_transform(df['type'])

df['region']=le.fit_transform(df['region'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  int32
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  int32
#  12  Month         18249 non-null  int64
#  13  Day           18249 non-null  int64
# dtypes: float64(9), int32(2), int64(3)
# memory usage: 1.8 MB

# %%
# Checking for Skewness

df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# Month            0.106617
# Day              0.014310
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
df_new = power_transform(df)

# %%
df=pd.DataFrame(df_new, columns=df.columns)

# %%
df.skew()
# Out:
# AveragePrice    0.005596
# Total Volume    0.011171
# 4046           -0.022679
# 4225           -0.017740
# 4770            0.032184
# Total Bags     -0.001626
# Small Bags      0.007058
# Large Bags     -0.073809
# XLarge Bags     0.793520
# type            0.000329
# year            0.213156
# region         -0.261443
# Month          -0.146584
# Day            -0.208462
# dtype: float64

# %% [markdown]
# We can see skewness removed from our dataset

# %%
plt.figure(figsize = (15,50))
graph = 1

for column in df:
    if graph <=15:
        ax = plt.subplot(5,3,graph)
        sns.boxplot(df[column], orient ='v')
        plt.xlabel(column,fontsize=10)
        plt.ylabel(column,fontsize=10)
    graph+=1   
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# We can see that some of our columns have outliers removing the outliers with Z-score technique

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region',
#        'Month', 'Day'],
#       dtype='object')

# %%
# Importing z-score
from scipy.stats import zscore

# %%
z_score = zscore(df[['AveragePrice','Total Bags',]])
abs_z_score = np.abs(z_score)

filtering_entry = (abs_z_score < 3).all(axis=1)

df= df[filtering_entry]

# %%
plt.figure(figsize = (15,50))
graph = 1

for column in df:
    if graph <=15:
        ax = plt.subplot(5,3,graph)
        sns.boxplot(df[column], orient ='v')
        plt.xlabel(column,fontsize=10)
        plt.ylabel(column,fontsize=10)
    graph+=1   
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# We can see only few outliers now, keeping as it is as not to lose data

# %%
df.shape
# Out:
# (18189, 14)

# %%
# Checking data lost

print ('Data lost = ', ((18249-18189)/18249)*100 , '%')
# Out:
# Data lost =  0.32878513891172123 %

# %% [markdown]
# ### Going for first part - Taking Avg price as Target and building Regression model¶

# %%
x = df.drop('AveragePrice', axis = 1 )
y = df['AveragePrice']

# %%
# Scaling data with Standard Scalaer
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_scaled
# Out:
# array([[-0.08549265, -0.65820783,  0.31060215, ..., -2.01002507,
#          1.49269275,  1.22971549],
#        [-0.15486587, -0.77678108,  0.23468696, ..., -2.01002507,
#          1.49269275,  0.54136901],
#        [ 0.18133456, -0.73173553,  0.58369061, ..., -2.01002507,
#          1.49269275, -0.21527848],
#        ...,
#        [-0.77269873, -0.61931421, -0.7727697 , ...,  1.54801022,
#         -1.64225369,  0.64321542],
#        [-0.69902335, -0.5495752 , -0.71061226, ...,  1.54801022,
#         -1.64225369, -0.10165701],
#        [-0.66464015, -0.36670376, -0.7854884 , ...,  1.54801022,
#         -1.64225369, -0.95463382]])

# %%
x = x_scaled

# %%
x
# Out:
# array([[-0.08549265, -0.65820783,  0.31060215, ..., -2.01002507,
#          1.49269275,  1.22971549],
#        [-0.15486587, -0.77678108,  0.23468696, ..., -2.01002507,
#          1.49269275,  0.54136901],
#        [ 0.18133456, -0.73173553,  0.58369061, ..., -2.01002507,
#          1.49269275, -0.21527848],
#        ...,
#        [-0.77269873, -0.61931421, -0.7727697 , ...,  1.54801022,
#         -1.64225369,  0.64321542],
#        [-0.69902335, -0.5495752 , -0.71061226, ...,  1.54801022,
#         -1.64225369, -0.10165701],
#        [-0.66464015, -0.36670376, -0.7854884 , ...,  1.54801022,
#         -1.64225369, -0.95463382]])

# %%
# Importing Linear Regression model for getting best random state 
from sklearn.linear_model import LinearRegression

# %%
# Dividing data into training and testing data

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
maxr2 = 0
maxRS=0

for i in range(0,350):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state=i)
    LR = LinearRegression()
    LR.fit(x_train,y_train)
    predf=LR.predict(x_test)
    r2_sc = r2_score(y_test, predf)
    
    if r2_sc>maxr2:
        maxr2=r2_sc
        macRS = i
print('Best R2score=',maxr2, "Random state=",macRS)
# Out:
# Best R2score= 0.5944040124264782 Random state= 233

# %%
# Spitting data into training and testing dataset
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state=233)

# %%
# Going for Linear Regression model
LR = LinearRegression()

LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predf=LR.predict(x_test)
r2_sc = r2_score(y_test, predf)
r2_sc
# Out:
# 0.5944040124264782

# %%
# Checking with KNN model
from sklearn.neighbors import KNeighborsRegressor

# %%
KN = KNeighborsRegressor()
KN.fit(x_train,y_train)

predf=KN.predict(x_test)
r2_sc = r2_score(y_test, predf)
r2_sc
# Out:
# 0.8224112732649592

# %%
# Checking for DecissionTreeRegressor
from sklearn.tree import DecisionTreeRegressor

DT =  DecisionTreeRegressor()

DT.fit(x_train,y_train)

predf=DT.predict(x_test)
r2_sc = r2_score(y_test, predf)
r2_sc
# Out:
# 0.7731677872901781

# %%
# Chacking for AdaBoostRegressor
from sklearn.ensemble import AdaBoostRegressor
AD =  AdaBoostRegressor()
AD.fit(x_train,y_train)

predf=AD.predict(x_test)
r2_sc = r2_score(y_test, predf)
r2_sc
# Out:
# 0.616583462813818

# %% [markdown]
# We can see that KNN is Performing better than rest of the models

# %% [markdown]
# Going gor Hyper_parametr_Tunning with Grid_search_CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'algorithm': ['kd_tree', 'brute'], 
              'leaf_size' : [10,11,14,15,18,20,25],
              'n_neighbors': [3,5,7,9,11,13],
             }

# %%
gridsearch = GridSearchCV(estimator=KN, param_grid=param_grid)

# %%
gridsearch.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'algorithm': ['kd_tree', 'brute'],
#                          'leaf_size': [10, 11, 14, 15, 18, 20, 25],
#                          'n_neighbors': [3, 5, 7, 9, 11, 13]})

# %%
gridsearch.best_params_
# Out:
# {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 5}

# %%
KNN = KNeighborsRegressor(algorithm = 'kd_tree', leaf_size=10 , n_neighbors=5)

# %%
KNN.fit(x_train,y_train)
y_pred = KNN.predict(x_test)

r2_sc = r2_score(y_test, y_pred)
r2_sc
# Out:
# 0.8224112732649592

# %% [markdown]
# Even Through we are getting same r2_score

# %%
print('Mean Absolute Error', mean_absolute_error(y_test,y_pred))
print('Mean Squered Error', mean_squared_error(y_test,y_pred))
print('Root Mean Absolute Error', np.sqrt(mean_absolute_error(y_test,y_pred)))
# Out:
# Mean Absolute Error 0.3204534384659514
# Mean Squered Error 0.18445445056013732
# Root Mean Absolute Error 0.5660860698391645

# %%
sns.scatterplot(x = y_test, y = y_pred)
plt.xlabel('Y_TEST')
plt.ylabel('Y-PREDICTED')
plt.show()

# %%
# Saving model
import joblib


joblib.dump(KNN,"Avacado_reg")
# Out:
# ['Avacado_reg']

# %% [markdown]
# ### Going for Second part - Taking Region as Target and building Classification model

# %%
x_new = df.drop('region', axis = 1)
y_new = df['region']

# %%
x_new
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0         -0.086248     -0.086605 -0.658619  0.307313 -0.247250   -0.524004
# 1         -0.034022     -0.155746 -0.776870  0.231647 -0.201041   -0.485890
# 2         -1.273938      0.179327 -0.731947  0.579503 -0.007072   -0.552018
# 3         -0.793421      0.003876 -0.634200  0.415100 -0.148322   -0.695449
# 4         -0.219440     -0.187640 -0.685293  0.224806 -0.137918   -0.669157
# ...             ...           ...       ...       ...       ...         ...
# 18244      0.640729     -0.674587 -0.467366 -0.919470 -1.238310   -0.334466
# 18245      0.816307     -0.767550 -0.619883 -0.665372 -1.238310   -0.496897
# 18246      1.147790     -0.771505 -0.619831 -0.772496  0.401546   -0.490952
# 18247      1.265876     -0.698077 -0.550282 -0.710543  0.401246   -0.424252
# 18248      0.618287     -0.663809 -0.367908 -0.785173  0.122919   -0.384961
#
#        Small Bags  Large Bags  XLarge Bags      type      year     Month  \
# 0       -0.340627   -0.773351    -0.699849 -0.999836 -1.221895  1.494347
# 1       -0.306425   -0.763435    -0.699849 -0.999836 -1.221895  1.494347
# 2       -0.366303   -0.750820    -0.699849 -0.999836 -1.221895  1.494347
# 3       -0.496853   -0.691865    -0.699849 -0.999836 -1.221895  1.494347
# 4       -0.477201   -0.600975    -0.699849 -0.999836 -1.221895  1.278438
# ...           ...         ...          ...       ...       ...       ...
# 18244   -0.178839   -0.410859    -0.699849  1.000164  1.968548 -1.220706
# 18245   -0.325977   -0.481465    -0.699849  1.000164  1.968548 -1.642047
# 18246   -0.308728   -0.943486    -0.699849  1.000164  1.968548 -1.642047
# 18247   -0.248932   -0.908510    -0.699849  1.000164  1.968548 -1.642047
# 18248   -0.212590   -1.042250    -0.699849  1.000164  1.968548 -1.642047
#
#             Day
# 0      1.229285
# 1      0.541005
# 2     -0.215570
# 3     -1.091311
# 4      1.416727
# ...         ...
# 18244 -1.382073
# 18245  1.323455
# 18246  0.642842
# 18247 -0.101959
# 18248 -0.954854
#
# [18189 rows x 13 columns]

# %%
y_new
# Out:
# 0       -2.011552
# 1       -2.011552
# 2       -2.011552
# 3       -2.011552
# 4       -2.011552
#            ...
# 18244    1.543838
# 18245    1.543838
# 18246    1.543838
# 18247    1.543838
# 18248    1.543838
# Name: region, Length: 18189, dtype: float64

# %%
y_new=le.fit_transform(y_new)

# %%
y_new
# Out:
# array([ 0,  0,  0, ..., 53, 53, 53], dtype=int64)

# %%
# Importing necessry classification models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
scaler = StandardScaler()

scaler.fit_transform
# Out:
# <bound method TransformerMixin.fit_transform of StandardScaler()>

# %%
maxAcc = 0
maxRS=0

for i in range(0,350):
    x_new_train,x_new_test,y_new_train,y_new_test = train_test_split(x_new,y_new,test_size=0.20, random_state=i)
    KNN = KNeighborsClassifier()
    KNN.fit(x_new_train,y_new_train)
    predf=KNN.predict(x_new_test)
    acc=accuracy_score(y_new_test, predf)
    
    if acc>maxAcc:
        maxAcc=acc
        macRS = i
print('Best Accuracy=',maxAcc, "Random state=",macRS)
# Out:
# Best Accuracy= 0.6715228147333699 Random state= 179

# %%
x_new_train,x_new_test,y_new_train,y_new_test = train_test_split(x_new,y_new,test_size=0.20, random_state=179)

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()
LR.fit(x_new_train,y_new_train)

predict_=LR.predict(x_new_test)

print("Accuracy",accuracy_score(y_new_test,predict_)*100)

print(confusion_matrix(y_new_test,predict_))
print(classification_report(y_new_test,predict_))
# Out:
# Accuracy 55.38757559098406
# [[46  0  0 ...  0  0  0]
#  [ 0 27  0 ...  0  0  0]
#  [ 0  0 45 ...  0  0  4]
#  ...
#  [ 0  0  0 ... 59  2  0]
#  [ 0  0  0 ...  0 62  0]
#  [ 0  0  1 ...  0  0 12]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.69      0.67        67
#            1       0.25      0.39      0.31        70
#            2       0.83      0.66      0.74        68
#            3       0.58      0.47      0.52        60
#            4       0.57      0.60      0.59        60
#            5       0.67      0.59      0.63        73
#            6       0.84      0.88      0.86        78
#            7       0.65      0.59      0.62        71
#            8       0.68      0.79      0.73        61
#            9       0.64      0.80      0.71        70
#           10       0.44      0.37      0.40        67
#           11       0.62      0.76      0.68        74
#           12       0.51      0.42      0.46        73
#           13       0.30      0.22      0.25        59
#           14       0.57      0.64      0.60        69
#           15       0.61      0.59      0.60        69
#           16       0.61      0.43      0.51        69
#           17       0.62      0.60      0.61        63
#           18       0.36      0.43      0.39        67
#           19       0.60      0.70      0.65        60
#           20       0.42      0.57      0.49        58
#           21       0.30      0.34      0.32        61
#           22       0.63      0.65      0.64        60
#           23       0.59      0.84      0.69        57
#           24       0.00      0.00      0.00        77
#           25       0.51      0.84      0.64        62
#           26       0.15      0.05      0.08        79
#           27       0.28      0.50      0.36        70
#           28       0.63      0.65      0.64        69
#           29       0.87      0.85      0.86        68
#           30       0.75      0.64      0.69        59
#           31       0.42      0.44      0.43        68
#           32       0.48      0.67      0.56        60
#           33       0.42      0.47      0.44        73
#           34       0.25      0.22      0.23        73
#           35       0.57      0.37      0.45        67
#           36       0.56      0.35      0.43        72
#           37       0.44      0.46      0.45        65
#           38       0.51      0.53      0.52        72
#           39       0.35      0.65      0.46        57
#           40       0.66      0.88      0.75        69
#           41       0.53      0.37      0.43        71
#           42       0.87      0.81      0.84        73
#           43       0.68      0.59      0.64        69
#           44       0.48      0.47      0.48        78
#           45       0.86      0.84      0.85        74
#           46       0.73      0.73      0.73        64
#           47       0.41      0.59      0.48        49
#           48       0.32      0.11      0.17        79
#           49       0.71      0.73      0.72        82
#           50       0.29      0.21      0.24        66
#           51       1.00      0.97      0.98        61
#           52       0.83      0.86      0.84        72
#           53       0.26      0.21      0.24        56
#
#     accuracy                           0.55      3638
#    macro avg       0.54      0.56      0.54      3638
# weighted avg       0.54      0.55      0.54      3638
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Checking with Random forest Classisfier
rf = RandomForestClassifier()

rf.fit(x_new_train,y_new_train)
pred = rf.predict(x_new_test)

print('Accuracy',accuracy_score(y_new_test,pred)*100)
print(confusion_matrix(y_new_test,pred))
print(classification_report(y_new_test,pred))
# Out:
# Accuracy 90.76415612974161
# [[63  0  0 ...  0  0  0]
#  [ 0 58  0 ...  0  0  0]
#  [ 0  0 67 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 61  0  0]
#  [ 0  0  0 ...  0 71  0]
#  [ 0  0  0 ...  0  0 49]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93        67
#            1       0.88      0.83      0.85        70
#            2       0.99      0.99      0.99        68
#            3       0.94      0.82      0.87        60
#            4       0.94      0.98      0.96        60
#            5       0.92      0.81      0.86        73
#            6       0.97      1.00      0.99        78
#            7       0.94      0.92      0.93        71
#            8       0.98      0.95      0.97        61
#            9       0.93      0.93      0.93        70
#           10       0.84      0.93      0.88        67
#           11       0.91      0.97      0.94        74
#           12       0.96      0.95      0.95        73
#           13       0.83      0.92      0.87        59
#           14       0.88      0.91      0.89        69
#           15       0.99      0.99      0.99        69
#           16       1.00      0.91      0.95        69
#           17       0.89      0.90      0.90        63
#           18       0.82      0.91      0.87        67
#           19       0.95      0.92      0.93        60
#           20       0.96      0.88      0.92        58
#           21       0.71      0.85      0.78        61
#           22       0.97      0.98      0.98        60
#           23       0.81      0.95      0.87        57
#           24       0.73      0.74      0.74        77
#           25       0.98      1.00      0.99        62
#           26       0.86      0.82      0.84        79
#           27       0.88      0.91      0.90        70
#           28       0.97      0.96      0.96        69
#           29       0.97      1.00      0.99        68
#           30       0.95      0.95      0.95        59
#           31       0.70      0.69      0.70        68
#           32       0.93      0.92      0.92        60
#           33       0.94      0.85      0.89        73
#           34       0.97      0.95      0.96        73
#           35       1.00      0.99      0.99        67
#           36       0.86      0.92      0.89        72
#           37       0.89      0.88      0.88        65
#           38       0.87      0.93      0.90        72
#           39       0.92      0.98      0.95        57
#           40       0.89      0.94      0.92        69
#           41       0.90      0.87      0.89        71
#           42       0.96      0.97      0.97        73
#           43       0.94      0.84      0.89        69
#           44       0.97      0.88      0.93        78
#           45       0.99      0.97      0.98        74
#           46       0.98      0.98      0.98        64
#           47       0.85      0.82      0.83        49
#           48       0.91      0.80      0.85        79
#           49       0.91      0.95      0.93        82
#           50       0.56      0.55      0.55        66
#           51       1.00      1.00      1.00        61
#           52       0.99      0.99      0.99        72
#           53       0.91      0.88      0.89        56
#
#     accuracy                           0.91      3638
#    macro avg       0.91      0.91      0.91      3638
# weighted avg       0.91      0.91      0.91      3638

# %%
# Support Vector Classifier

svc=SVC()

# %%
svc.fit(x_new_train,y_new_train)
new_pred = svc.predict(x_new_test)

print('Accuracy',accuracy_score(y_new_test,new_pred)*100)
print(confusion_matrix(y_new_test,new_pred))
print(classification_report(y_new_test,new_pred))
# Out:
# Accuracy 80.04398020890599
# [[62  0  0 ...  0  0  0]
#  [ 0 44  0 ...  0  0  0]
#  [ 0  0 66 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 61  0  0]
#  [ 0  0  0 ...  0 72  0]
#  [ 0  0  1 ...  0  0 39]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.93      0.79        67
#            1       0.57      0.63      0.60        70
#            2       0.96      0.97      0.96        68
#            3       0.88      0.73      0.80        60
#            4       0.94      0.85      0.89        60
#            5       0.89      0.67      0.77        73
#            6       0.99      0.97      0.98        78
#            7       0.87      0.73      0.79        71
#            8       0.95      0.95      0.95        61
#            9       0.76      0.74      0.75        70
#           10       0.56      0.76      0.65        67
#           11       0.83      0.91      0.86        74
#           12       0.86      0.96      0.91        73
#           13       0.53      0.64      0.58        59
#           14       0.81      0.96      0.88        69
#           15       0.96      1.00      0.98        69
#           16       0.97      0.90      0.93        69
#           17       0.92      0.92      0.92        63
#           18       0.71      0.76      0.73        67
#           19       0.82      0.77      0.79        60
#           20       1.00      0.81      0.90        58
#           21       0.49      0.69      0.58        61
#           22       0.97      0.95      0.96        60
#           23       0.72      0.84      0.77        57
#           24       0.73      0.49      0.59        77
#           25       0.97      1.00      0.98        62
#           26       0.77      0.47      0.58        79
#           27       0.66      0.67      0.67        70
#           28       0.99      0.96      0.97        69
#           29       1.00      1.00      1.00        68
#           30       0.84      0.83      0.84        59
#           31       0.52      0.66      0.58        68
#           32       0.91      0.87      0.89        60
#           33       0.65      0.66      0.65        73
#           34       0.73      0.77      0.75        73
#           35       0.90      0.90      0.90        67
#           36       0.88      0.81      0.84        72
#           37       0.62      0.69      0.65        65
#           38       0.62      0.69      0.66        72
#           39       0.70      0.84      0.76        57
#           40       0.82      0.93      0.87        69
#           41       0.81      0.72      0.76        71
#           42       0.95      0.95      0.95        73
#           43       0.92      0.80      0.85        69
#           44       0.79      0.63      0.70        78
#           45       0.97      0.91      0.94        74
#           46       0.86      0.92      0.89        64
#           47       0.67      0.80      0.73        49
#           48       0.81      0.58      0.68        79
#           49       0.88      0.82      0.85        82
#           50       0.33      0.29      0.31        66
#           51       1.00      1.00      1.00        61
#           52       0.99      1.00      0.99        72
#           53       0.74      0.70      0.72        56
#
#     accuracy                           0.80      3638
#    macro avg       0.81      0.80      0.80      3638
# weighted avg       0.81      0.80      0.80      3638

# %%
from sklearn.model_selection import cross_val_score

# %%
scr = cross_val_score(LR, x_new,y_new, cv=8)
print("Cross validation score for Logistic Regression is", scr.mean())


scr = cross_val_score(rf, x_new,y_new, cv=8)
print("Cross validation score for Random Forest is", scr.mean())


scr = cross_val_score(svc,x_new,y_new, cv=8)
print("Cross validation score for SVC is", scr.mean())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross validation score for Logistic Regression is 0.4496709295500195
# Cross validation score for Random Forest is 0.7670478091441691
# Cross validation score for SVC is 0.6724861486278639

# %% [markdown]
# Though it shows that logisctic regression is best performing model it does not have more parameters to tune also there is very less diffrance between support vector and LR model so going for tunning parameters for Support Vector

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}

# %%
grids = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)

# %%
grids.fit(x_new_train,y_new_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=  16.0s
# [CV 2/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=  16.8s
# [CV 3/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=  17.2s
# [CV 4/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=  17.1s
# [CV 5/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=  17.2s
# [CV 1/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=  13.5s
# [CV 2/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=  13.5s
# [CV 3/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=  13.9s
# [CV 4/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=  14.0s
# [CV 5/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=  13.0s
# [CV 1/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=  16.1s
# [CV 2/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=  15.2s
# [CV 3/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=  15.6s
# [CV 4/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=  15.7s
# [CV 5/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=  15.5s
# [CV 1/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=  15.8s
# [CV 2/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=  16.1s
# [CV 3/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=  16.5s
# [CV 4/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=  17.4s
# [CV 5/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=  16.7s
# [CV 1/5] END ................C=0.1, gamma=0.0001, kernel=rbf; total time=  16.8s
# [CV 2/5] END ................C=0.1, gamma=0.0001, kernel=rbf; total time=  16.7s
# [CV 3/5] END ................C=0.1, gamma=0.0001, kernel=rbf; total time=  17.3s
# [CV 4/5] END ................C=0.1, gamma=0.0001, kernel=rbf; total time=  17.3s
# [CV 5/5] END ................C=0.1, gamma=0.0001, kernel=rbf; total time=  16.8s
# [CV 1/5] END .......................C=1, gamma=1, kernel=rbf; total time=  17.8s
# [CV 2/5] END .......................C=1, gamma=1, kernel=rbf; total time=  18.1s
# [CV 3/5] END .......................C=1, gamma=1, kernel=rbf; total time=  18.6s
# [CV 4/5] END .......................C=1, gamma=1, kernel=rbf; total time=  18.0s
# [CV 5/5] END .......................C=1, gamma=1, kernel=rbf; total time=  18.6s
# [CV 1/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   8.9s
# [CV 2/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   9.1s
# [CV 3/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   9.1s
# [CV 4/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   8.5s
# [CV 5/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   8.8s
# [CV 1/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=  11.4s
# [CV 2/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=  11.3s
# [CV 3/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=  11.9s
# [CV 4/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=  11.7s
# [CV 5/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=  11.7s
# [CV 1/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=  15.5s
# [CV 2/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=  15.8s
# [CV 3/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=  16.5s
# [CV 4/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=  15.4s
# [CV 5/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=  15.1s
# [CV 1/5] END ..................C=1, gamma=0.0001, kernel=rbf; total time=  17.2s
# [CV 2/5] END ..................C=1, gamma=0.0001, kernel=rbf; total time=  17.3s
# [CV 3/5] END ..................C=1, gamma=0.0001, kernel=rbf; total time=  16.6s
# [CV 4/5] END ..................C=1, gamma=0.0001, kernel=rbf; total time=  17.2s
# [CV 5/5] END ..................C=1, gamma=0.0001, kernel=rbf; total time=  15.9s
# [CV 1/5] END ......................C=10, gamma=1, kernel=rbf; total time=  18.3s
# [CV 2/5] END ......................C=10, gamma=1, kernel=rbf; total time=  18.3s
# [CV 3/5] END ......................C=10, gamma=1, kernel=rbf; total time=  17.9s
# [CV 4/5] END ......................C=10, gamma=1, kernel=rbf; total time=  18.6s
# [CV 5/5] END ......................C=10, gamma=1, kernel=rbf; total time=  18.9s
# [CV 1/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   7.4s
# [CV 2/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   7.1s
# [CV 3/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   7.7s
# [CV 4/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   7.7s
# [CV 5/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   7.4s
# [CV 1/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   8.0s
# [CV 2/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   8.1s
# [CV 3/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   7.8s
# [CV 4/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   8.2s
# [CV 5/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   7.9s
# [CV 1/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=  11.5s
# [CV 2/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=  10.8s
# [CV 3/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=  11.4s
# [CV 4/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=  11.8s
# [CV 5/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=  11.8s
# [CV 1/5] END .................C=10, gamma=0.0001, kernel=rbf; total time=  15.6s
# [CV 2/5] END .................C=10, gamma=0.0001, kernel=rbf; total time=  15.3s
# [CV 3/5] END .................C=10, gamma=0.0001, kernel=rbf; total time=  15.6s
# [CV 4/5] END .................C=10, gamma=0.0001, kernel=rbf; total time=  15.4s
# [CV 5/5] END .................C=10, gamma=0.0001, kernel=rbf; total time=  15.8s
# [CV 1/5] END .....................C=100, gamma=1, kernel=rbf; total time=  18.5s
# [CV 2/5] END .....................C=100, gamma=1, kernel=rbf; total time=  18.8s
# [CV 3/5] END .....................C=100, gamma=1, kernel=rbf; total time=  17.7s
# [CV 4/5] END .....................C=100, gamma=1, kernel=rbf; total time=  18.8s
# [CV 5/5] END .....................C=100, gamma=1, kernel=rbf; total time=  18.8s
# [CV 1/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   7.3s
# [CV 2/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   7.1s
# [CV 3/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   7.0s
# [CV 4/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   6.8s
# [CV 5/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   6.8s
# [CV 1/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   6.1s
# [CV 2/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   6.3s
# [CV 3/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   6.4s
# [CV 4/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   6.7s
# [CV 5/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   6.6s
# [CV 1/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   8.3s
# [CV 2/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   8.2s
# [CV 3/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   8.4s
# [CV 4/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   8.9s
# [CV 5/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   8.7s
# [CV 1/5] END ................C=100, gamma=0.0001, kernel=rbf; total time=  12.0s
# [CV 2/5] END ................C=100, gamma=0.0001, kernel=rbf; total time=  11.0s
# [CV 3/5] END ................C=100, gamma=0.0001, kernel=rbf; total time=  11.0s
# [CV 4/5] END ................C=100, gamma=0.0001, kernel=rbf; total time=  11.7s
# [CV 5/5] END ................C=100, gamma=0.0001, kernel=rbf; total time=  11.4s
# [CV 1/5] END ....................C=1000, gamma=1, kernel=rbf; total time=  19.0s
# [CV 2/5] END ....................C=1000, gamma=1, kernel=rbf; total time=  18.9s
# [CV 3/5] END ....................C=1000, gamma=1, kernel=rbf; total time=  18.8s
# [CV 4/5] END ....................C=1000, gamma=1, kernel=rbf; total time=  18.8s
# [CV 5/5] END ....................C=1000, gamma=1, kernel=rbf; total time=  19.2s
# [CV 1/5] END ..................C=1000, gamma=0.1, kernel=rbf; total time=   8.0s
# [CV 2/5] END ..................C=1000, gamma=0.1, kernel=rbf; total time=   7.3s
# [CV 3/5] END ..................C=1000, gamma=0.1, kernel=rbf; total time=   7.2s
# [CV 4/5] END ..................C=1000, gamma=0.1, kernel=rbf; total time=   7.2s
# [CV 5/5] END ..................C=1000, gamma=0.1, kernel=rbf; total time=   7.4s
# [CV 1/5] END .................C=1000, gamma=0.01, kernel=rbf; total time=   6.9s
# [CV 2/5] END .................C=1000, gamma=0.01, kernel=rbf; total time=  10.3s
# [CV 3/5] END .................C=1000, gamma=0.01, kernel=rbf; total time=   6.6s
# [CV 4/5] END .................C=1000, gamma=0.01, kernel=rbf; total time=   6.9s
# [CV 5/5] END .................C=1000, gamma=0.01, kernel=rbf; total time=   6.4s
# [CV 1/5] END ................C=1000, gamma=0.001, kernel=rbf; total time=   7.2s
# [CV 2/5] END ................C=1000, gamma=0.001, kernel=rbf; total time=   6.9s
# [CV 3/5] END ................C=1000, gamma=0.001, kernel=rbf; total time=   7.1s
# [CV 4/5] END ................C=1000, gamma=0.001, kernel=rbf; total time=   7.2s
# [CV 5/5] END ................C=1000, gamma=0.001, kernel=rbf; total time=   7.1s
# [CV 1/5] END ...............C=1000, gamma=0.0001, kernel=rbf; total time=   8.6s
# [CV 2/5] END ...............C=1000, gamma=0.0001, kernel=rbf; total time=   8.5s
# [CV 3/5] END ...............C=1000, gamma=0.0001, kernel=rbf; total time=   8.5s
# [CV 4/5] END ...............C=1000, gamma=0.0001, kernel=rbf; total time=   8.6s
# [CV 5/5] END ...............C=1000, gamma=0.0001, kernel=rbf; total time=   9.4s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
print(grids.best_params_)
# Out:
# {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
print(grids.best_estimator_)
# Out:
# SVC(C=100, gamma=0.1)

# %%
grid_predictions = grids.predict(x_new_test)

# %%
print('Accuracy',accuracy_score(y_new_test,grid_predictions)*100)
print(confusion_matrix(y_new_test,grid_predictions))
print(classification_report(y_new_test,grid_predictions))
# Out:
# Accuracy 91.58878504672897
# [[65  0  0 ...  0  0  0]
#  [ 0 60  0 ...  0  0  0]
#  [ 0  0 67 ...  0  0  1]
#  ...
#  [ 0  0  0 ... 61  0  0]
#  [ 0  0  0 ...  0 72  0]
#  [ 0  0  0 ...  0  0 51]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93        67
#            1       0.80      0.86      0.83        70
#            2       0.99      0.99      0.99        68
#            3       0.87      0.88      0.88        60
#            4       0.98      1.00      0.99        60
#            5       0.91      0.82      0.86        73
#            6       1.00      1.00      1.00        78
#            7       0.91      0.97      0.94        71
#            8       0.97      1.00      0.98        61
#            9       0.88      0.90      0.89        70
#           10       0.76      0.85      0.80        67
#           11       0.95      0.97      0.96        74
#           12       0.96      0.99      0.97        73
#           13       0.83      0.81      0.82        59
#           14       0.90      0.96      0.93        69
#           15       1.00      1.00      1.00        69
#           16       0.94      0.91      0.93        69
#           17       0.93      0.90      0.92        63
#           18       0.90      0.90      0.90        67
#           19       0.90      0.90      0.90        60
#           20       0.98      0.86      0.92        58
#           21       0.79      0.92      0.85        61
#           22       0.98      1.00      0.99        60
#           23       0.85      0.89      0.87        57
#           24       0.84      0.74      0.79        77
#           25       0.98      1.00      0.99        62
#           26       0.82      0.80      0.81        79
#           27       0.93      0.91      0.92        70
#           28       0.97      0.99      0.98        69
#           29       1.00      1.00      1.00        68
#           30       0.94      0.98      0.96        59
#           31       0.76      0.78      0.77        68
#           32       0.95      0.95      0.95        60
#           33       0.91      0.96      0.93        73
#           34       1.00      0.92      0.96        73
#           35       0.97      0.97      0.97        67
#           36       0.89      0.89      0.89        72
#           37       0.94      0.91      0.92        65
#           38       0.89      0.90      0.90        72
#           39       0.91      0.91      0.91        57
#           40       0.91      0.88      0.90        69
#           41       0.92      0.83      0.87        71
#           42       0.99      0.95      0.97        73
#           43       0.94      0.87      0.90        69
#           44       0.97      0.90      0.93        78
#           45       1.00      0.99      0.99        74
#           46       0.98      0.97      0.98        64
#           47       0.88      0.94      0.91        49
#           48       0.91      0.81      0.86        79
#           49       0.92      0.96      0.94        82
#           50       0.62      0.64      0.63        66
#           51       1.00      1.00      1.00        61
#           52       1.00      1.00      1.00        72
#           53       0.91      0.91      0.91        56
#
#     accuracy                           0.92      3638
#    macro avg       0.92      0.92      0.92      3638
# weighted avg       0.92      0.92      0.92      3638

# %%
# Saving Model

import joblib


joblib.dump(grids.best_estimator_,"Avacado_class")
# Out:
# ['Avacado_class']
